# %%
import pandas as pd

# %%
pd.read_csv("facebook_ads_electric_vehicles_with_classifications.csv")
# Out:
#          ad_archive_id          page_id                      page_name  \
# 0      329729626383284  103393094402445                    SEAT Βελμάρ
# 1      329729626383284  103393094402445                    SEAT Βελμάρ
# 2      329729626383284  103393094402445                    SEAT Βελμάρ
# 3     1186630002407631  105049314838170                          CUPRA
# 4     1186630002407631  105049314838170                          CUPRA
# ...                ...              ...                            ...
# 1466  1801482500787239  267475826771300           Camelback Volkswagen
# 1467  1061133096028559  104401666267037  Volkswagen of North Nashville
# 1468  1015935744050730  182271785148934             Kendall VW of Bend
# 1469  1346597916407608  196153007086880                Classic Hyundai
# 1470   729019106294690  710391195480124      Universal Hyundai Orlando
#
#       advertiser_name  advertiser_id                               ad_title  \
# ...
